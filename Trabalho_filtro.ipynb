# %%
df_2020 = spark.read.format("parquet").option("inferSchema", "true").option("header","true").load("/FileStore/tables/inmet_2020_parquet-1.gz")
display(df_2020)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df_2021 = spark.read.format("parquet").option("inferSchema", "true").option("header","true").load("/FileStore/tables/inmet_2021_parquet.gz")
display(df_2021)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df_2022 = spark.read.format("parquet").option("inferSchema", "true").option("header","true").load("/FileStore/tables/inmet_2022_parquet.gz")
display(df_2022)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# !pip install --upgrade pip
# Out:
# ...
#      |████████████████████████████████| 2.1 MB 7.1 MB/s
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 21.0.1
#     Uninstalling pip-21.0.1:
#       Successfully uninstalled pip-21.0.1
# ...

# %%
# !pip install sweetviz
# !pip install pandas

# %%
# !pip install -q findspark
# !pip install o pyspark
# !pip install pyarrow

# %%
from zipfile import ZipFile
import decimal as D
import os
import requests
import csv
import pandas as pd
import findspark
import sweetviz as sw
import pyarrow
from pyspark.sql import SparkSession
import numpy as np

# %%
# Selecione colunas por tipos de dados
df_2020.dtypes
# Out:
# Out[22]: [('Data', 'timestamp'),
#  ('Hora UTC', 'string'),
#  ('PRECIPITAÇÃO TOTAL, HORÁRIO (mm)', 'decimal(3,1)'),
#  ('PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)', 'decimal(4,1)'),
#  ('PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)', 'decimal(4,1)'),
#  ('PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)', 'decimal(4,1)'),
#  ('RADIACAO GLOBAL (Kj/m²)', 'decimal(5,1)'),
#  ('TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)', 'decimal(3,1)'),
#  ('TEMPERATURA DO PONTO DE ORVALHO (°C)', 'decimal(3,1)'),
#  ('TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)', 'decimal(3,1)'),
#  ('TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)', 'decimal(3,1)'),
#  ('TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)', 'decimal(3,1)'),
#  ('TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)', 'decimal(3,1)'),
#  ('UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)', 'decimal(3,1)'),
#  ('UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)', 'decimal(3,1)'),
#  ('UMIDADE RELATIVA DO AR, HORARIA (%)', 'decimal(3,1)'),
# ...

# %%
# Summary
df_2020.describe()
# Out:
# Out[68]: DataFrame[summary: string, Hora UTC: string, PRECIPITAÇÃO TOTAL, HORÁRIO (mm): string, PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB): string, PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB): string, PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB): string, RADIACAO GLOBAL (Kj/m²): string, TEMPERATURA DO AR - BULBO SECO, HORARIA (°C): string, TEMPERATURA DO PONTO DE ORVALHO (°C): string, TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C): string, TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C): string, TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C): string, TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C): string, UMIDADE REL. MAX. NA HORA ANT. (AUT) (%): string, UMIDADE REL. MIN. NA HORA ANT. (AUT) (%): string, UMIDADE RELATIVA DO AR, HORARIA (%): string, VENTO, DIREÇÃO HORARIA (gr) (° (gr)): string, VENTO, RAJADA MAXIMA (m/s): string, VENTO, VELOCIDADE HORARIA (m/s): string, estacao_ano: string, dias: string, ano: string, mes: string, REGIAO:: string, UF:: string, ESTACAO:: st
# ...

# %%
# Verificando nome das colunas
df_2020.columns
# Out:
# Out[70]: ['Data',
#  'Hora UTC',
#  'PRECIPITAÇÃO TOTAL, HORÁRIO (mm)',
#  'PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)',
#  'PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)',
#  'PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)',
#  'RADIACAO GLOBAL (Kj/m²)',
#  'TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)',
#  'TEMPERATURA DO PONTO DE ORVALHO (°C)',
#  'TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)',
#  'TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)',
#  'TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)',
#  'TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)',
#  'UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)',
#  'UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)',
#  'UMIDADE RELATIVA DO AR, HORARIA (%)',
#  'VENTO, DIREÇÃO HORARIA (gr) (° (gr))',
#  'VENTO, RAJADA MAXIMA (m/s)',
#  'VENTO, VELOCIDADE HORARIA (m/s)',
#  'estacao_ano',
#  'dias',
#  'ano',
#  'mes',
#  'REGIAO:',
#  'UF:',
#  'ESTACAO:',
#  'CODIGO (WMO):',
#  'LATITUDE:',
#  'LONGITUDE:',
#  'ALTITUDE:']

# %%
# Returna o número de linhas do Dataset
df_2020.count()
# Out:
# Out[89]: 8784

# %%
# Filtra linhas usando uma condição fornecida
display(df_2020.filter("mes = 2"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# Importe a função para retornar uma coluna
from pyspark.sql.functions import col
 
display(df_2020.select(col("Data")))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
